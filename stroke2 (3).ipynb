# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse, r2_score as r2

# %% [markdown]
# According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths.
# This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.
#
# Attribute Information
# 1. id: unique identifier
# 2. gender: "Male", "Female" or "Other"
# 3. age: age of the patient
# 4.  hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# 5. heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# 6. ever_married: "No" or "Yes"
# 7. work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# 8. Residence_type: "Rural" or "Urban"
# 9. avg_glucose_level: average glucose level in blood
# 10. bmi: body mass index
# 11. smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
# 12. stroke: 1 if the patient had a stroke or 0 if not
# *Note: "Unknown" in smoking_status means that the information is unavailable for this patient

# %%
df = pd.read_csv('/content/stroke.zip')
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
num = df.select_dtypes(include=np.number)
cat = df.select_dtypes(include='object')

# %%
df = pd.read_csv('/content/stroke.zip')
num = df.select_dtypes(include=np.number)
cat = df.select_dtypes(include='object')
num = num.drop('id', axis=1)
num.head()
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 0  67.0             0              1             228.69  36.6       1
# 1  61.0             0              0             202.21   NaN       1
# 2  80.0             0              1             105.92  32.5       1
# 3  49.0             0              0             171.23  34.4       1
# 4  79.0             1              0             174.12  24.0       1

# %%
sample = num.sample(50)
sample.head()
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 1538  54.0             0              0              77.52  35.8       0
# 1966  40.0             0              0              75.40  28.7       0
# 625   40.0             0              0              71.20  27.1       0
# 1264  38.0             0              0              69.34  43.7       0
# 744   71.0             1              0             194.62  31.6       0

# %%
sns.pairplot(num, hue ='hypertension', palette = 'magma')
plt.show()

# %%
sns.pairplot(num, hue ='hypertension', palette = 'rocket')
plt.show()

# %%
corr_matrix = sample.corr()
corr_matrix
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.279455       0.382864           0.371558
# hypertension       0.279455      1.000000       0.111111           0.406906
# heart_disease      0.382864      0.111111       1.000000           0.121199
# avg_glucose_level  0.371558      0.406906       0.121199           1.000000
# bmi                0.476356      0.227706      -0.045941           0.322587
# stroke             0.167808     -0.084215       0.196502           0.303941
#
#                         bmi    stroke
# age                0.476356  0.167808
# hypertension       0.227706 -0.084215
# heart_disease     -0.045941  0.196502
# avg_glucose_level  0.322587  0.303941
# bmi                1.000000  0.251178
# stroke             0.251178  1.000000

# %%
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.show(
)

# %%
def select_if_bmi_greater_than_30(sample):
  return sample[sample['bmi'] > 30]

select_if_bmi_greater_than_30(sample)
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 1538  54.0             0              0              77.52  35.8       0
# 1264  38.0             0              0              69.34  43.7       0
# 744   71.0             1              0             194.62  31.6       0
# 2863  58.0             0              0              73.36  36.6       0
# 4643  33.0             0              0              57.10  33.1       0
# 113   45.0             0              0             224.10  56.6       1
# 3259  30.0             0              0              79.55  33.7       0
# 4129  78.0             0              0             208.99  31.4       0
# 575   45.0             0              0              99.97  35.6       0
# 4588  62.0             1              0             199.78  45.2       0
# 1822  25.0             0              0              81.54  43.1       0
# 3198  63.0             1              0             228.20  37.7       0
# 515   28.0             0              0             183.45  40.5       0
# 2568  69.0             1              0              87.93  33.6       0
# 4627  65.0             0              0             172.86  34.4       0
# 2693  77.0             0              0             250.80  32.9       0
# 2797  73.0             0              0              98.34  30.9       0
# 3660  52.0             0              0              67.30  36.3       0

# %%
bmis = select_if_bmi_greater_than_30(num)
bmis.head()
# Out:
#      age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 0   67.0             0              1             228.69  36.6       1
# 2   80.0             0              1             105.92  32.5       1
# 3   49.0             0              0             171.23  34.4       1
# 11  61.0             0              1             120.46  36.8       1
# 15  50.0             1              0             167.41  30.9       1

# %%
bmis.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  1893.000000   1893.000000    1893.000000        1893.000000
# mean     49.691918      0.143687       0.062335         114.254152
# std      17.196861      0.350865       0.241827          51.892290
# min       0.800000      0.000000       0.000000          55.260000
# 25%      37.000000      0.000000       0.000000          78.740000
# 50%      51.000000      0.000000       0.000000          93.960000
# 75%      62.000000      0.000000       0.000000         127.400000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  1893.000000  1893.000000
# mean     36.550555     0.050713
# std       6.255820     0.219469
# min      30.100000     0.000000
# 25%      32.100000     0.000000
# 50%      34.700000     0.000000
# 75%      39.200000     0.000000
# max      97.600000     1.000000

# %%
bmis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1893 entries, 0 to 5107
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1893 non-null   float64
#  1   hypertension       1893 non-null   int64
#  2   heart_disease      1893 non-null   int64
#  3   avg_glucose_level  1893 non-null   float64
#  4   bmi                1893 non-null   float64
#  5   stroke             1893 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 103.5 KB

# %%
#bmi vs stroke

bmi_vs_stroke = bmis['stroke'].value_counts()
bmi_vs_stroke
# Out:
# stroke
# 0    1797
# 1      96
# Name: count, dtype: int64

# %%
#bmi cs stroke

bmi_vs_stroke.plot(kind='bar', color=['red', 'green'])
plt.show()

# %%
bmi_vs_stroke = sample.groupby('bmi')['stroke'].value_counts().sum()
bmi_vs_stroke
# Out:
# np.int64(48)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
num.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke'],
#       dtype='object')

# %%
cat.columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
df = pd.read_csv('/content/stroke.zip')
num = df.select_dtypes(include=np.number)
cat = df.select_dtypes(include='object')
num = num.drop('id', axis=1)
num.head()
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 0  67.0             0              1             228.69  36.6       1
# 1  61.0             0              0             202.21   NaN       1
# 2  80.0             0              1             105.92  32.5       1
# 3  49.0             0              0             171.23  34.4       1
# 4  79.0             1              0             174.12  24.0       1

# %%
gender = df['gender'].value_counts()
gender
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
gender.drop('Other', axis=0,inplace = True)
gender.value_counts()
gender
# Out:
# gender
# Female    2994
# Male      2115
# Name: count, dtype: int64

# %%
sns.barplot(gender, palette='rocket')
plt.show()

# %%
cat.columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
sns.countplot(df['ever_married'], palette='rocket')
plt.show()

# %%
sns.countplot(df['work_type'], palette='rocket')
plt.show()

df['work_type'].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
never_worked = df[df['work_type'] == 'Never_worked']['work_type'].value_counts()
sns.boxplot(never_worked, palette='viridis')
plt.show()

# %%
# bivariate analysis
num.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke'],
#       dtype='object')

# %%
# heart disease vs bmi

h_vs_bmi = df.groupby('heart_disease')['bmi'].value_counts()
h_vs_bmi
# Out:
# heart_disease  bmi
# 0              28.7    39
#                28.4    36
#                23.4    35
#                26.1    35
#                27.6    35
#                        ..
# 1              42.7     1
#                43.9     1
#                44.5     1
#                45.7     1
#                54.7     1
# Name: count, Length: 561, dtype: int64

# %%
h_vs_bmi = h_vs_bmi.sample(50)
h_vs_bmi.plot(kind='bar', color=['red', 'green'])
plt.show()

# %%
# bmi vs hypertension

b_vs_hy = df.groupby('bmi')['hypertension'].value_counts()
b_vs_hy
# Out:
# bmi   hypertension
# 10.3  0               1
# 11.3  0               1
# 11.5  0               1
# 12.0  0               1
# 12.3  0               1
#                      ..
# 66.8  0               1
# 71.9  0               1
# 78.0  1               1
# 92.0  1               1
# 97.6  1               1
# Name: count, Length: 620, dtype: int64

# %%
df['bmi'].isnull()
df['bmi'].fillna(df['bmi'].mean(), inplace=True)

# %%
df = pd.read_csv('/content/stroke.zip')
num = df.select_dtypes(include=np.number)
cat = df.select_dtypes(include='object')
cat.columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
num.columns
# Out:
# Index(['id', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level',
#        'bmi', 'stroke'],
#       dtype='object')

# %%
cat.columns
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status'],
#       dtype='object')

# %%
i = num.dropna(axis=0,inplace=True)

# %%
sample1 = pd.DataFrame({'Actual': b_test, 'Predicted': b_pred}).sample(50)
sample1
# Out:
#       Actual  Predicted
# 540        0   0.014438
# 3598       0   0.049388
# 1938       0   0.090195
# 1395       0   0.041580
# 3257       0   0.073977
# 1436       0   0.121821
# 802        0   0.092507
# 4711       0   0.144305
# 927        0   0.067520
# 4416       0   0.012822
# 4421       0  -0.006086
# 1569       0   0.028366
# 226        1   0.123557
# 4751       0   0.033117
# 4111       0   0.027971
# 5007       0   0.056660
# 1449       0  -0.004308
# 3084       0   0.057937
# 2680       0   0.056935
# 1980       0  -0.006733
# 1513       0   0.001667
# 409        0   0.087899
# 1965       0  -0.016286
# 925        0  -0.023216
# 398        0   0.007944
# 3148       0   0.119658
# 2527       0   0.165603
# 2890       0   0.096721
# 2209       0   0.124066
# 2202       0   0.130341
# 4752       0  -0.028694
# 2208       0   0.068483
# 53         1   0.137336
# 3969       0   0.052955
# 852        0  -0.020462
# 3194       0   0.063050
# 3477       0  -0.018383
# 4831       0  -0.030856
# 3620       0   0.040923
# 4793       0  -0.009257
# 3937       0  -0.012272
# 279        0   0.006322
# 2915       0  -0.014566
# 861        0   0.070185
# 5088       0   0.100169
# 2507       0   0.066366
# 1801       0   0.048170
# 1240       0   0.102033
# 1096       0   0.010189
# 563        0   0.119199

# %%
sns.barplot(x=sample1['Actual'], y=sample1['Predicted'], hue=df['gender'], )
plt.xlabel('stroke')
plt.ylabel('count')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
x = num.drop('stroke', axis=1)
y = num['stroke']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred

sns.distplot(y_test - y_pred, color='y')
plt.show()

# %%
model = RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.lineplot(x=y_test, y=y_pred)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1401
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.95      1473
#    macro avg       0.48      0.50      0.49      1473
# weighted avg       0.90      0.95      0.93      1473
#
# [[1400    1]
#  [  72    0]]

# %%
from sklearn.svm import SVC as SupportVectorClassifier
model = SupportVectorClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1401
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.95      1473
#    macro avg       0.48      0.50      0.49      1473
# weighted avg       0.90      0.95      0.93      1473
#
# [[1401    0]
#  [  72    0]]

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.lineplot(confusion_matrix(y_test, y_pred), palette = 'magma')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1401
#            1       0.08      0.07      0.07        72
#
#     accuracy                           0.91      1473
#    macro avg       0.52      0.51      0.51      1473
# weighted avg       0.91      0.91      0.91      1473
#
# [[1342   59]
#  [  67    5]]

# %%
model = GaussianNB()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.lineplot(confusion_matrix(y_test, y_pred), palette = 'rocket')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94      1401
#            1       0.19      0.43      0.26        72
#
#     accuracy                           0.88      1473
#    macro avg       0.58      0.67      0.60      1473
# weighted avg       0.93      0.88      0.90      1473
#
# [[1267  134]
#  [  41   31]]

# %%
model = KNeighborsClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.show()

sns.lineplot(x=y_test, y=y_pred)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1401
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.95      1473
#    macro avg       0.48      0.50      0.49      1473
# weighted avg       0.90      0.95      0.93      1473
#
# [[1396    5]
#  [  72    0]]

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

sns.lineplot(x=y_test, y=y_pred, color='g')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1401
#            1       0.11      0.11      0.11        72
#
#     accuracy                           0.91      1473
#    macro avg       0.53      0.53      0.53      1473
# weighted avg       0.91      0.91      0.91      1473
#
# [[1339   62]
#  [  64    8]]
